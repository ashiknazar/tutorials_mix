# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.metrics import mean_squared_error

# %%
import pandas as pd

# %%
data=pd.read_csv('Salary_Data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
import seaborn as sns

# %%
sns.scatterplot(data=data,x='YearsExperience',y='Salary')
# Out:
# <AxesSubplot: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.pairplot(data=data)

# %%
sns.displot(data['YearsExperience'])

# %%
sns.histplot(data['YearsExperience'],kde=True)
# Out:
# <AxesSubplot: xlabel='YearsExperience', ylabel='Count'>

# %%
sns.kdeplot(data['YearsExperience'])
# Out:
# <AxesSubplot: xlabel='YearsExperience', ylabel='Density'>

# %%
model=LinearRegression()

# %%
X=data.iloc[:,:-1].values  

Y=data.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=42)
for i in x_train:
    print(i,end="")
# Out:
# [1.1][2.2][5.1][2.9][4.1][4.][7.9][1.3][1.5][9.][2.][7.1][9.5][5.9][10.5][6.8][3.2][3.9][4.5][6.][3.]

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9414466227178214

# %%
mae=mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 5161.328710400183

# %%
import numpy as np
rmse=np.sqrt(mae)

# %%
rmse
# Out:
# 71.84238797813018

# %%
mse=mean_squared_error(y_pred,y_test)
mse
# Out:
# 37784662.46621314

# %%
import matplotlib.pyplot as plt
plt.scatter(x=x_test,y=y_test)
plt.scatter(x=x_test,y=y_pred,color='r')

# %%
yy=model.predict([[15]])

# %%
yy
# Out:
# array([166004.66419212])

# %%
df=pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X=df.iloc[:,:-1].values
Y=df.iloc[:,1].values

# %%
dat=pd.get_dummies(df['State'],drop_first=True)

# %%
df=pd.concat([df,dat],axis=1)
ddf=df.drop(['State'],axis=1)
ddf
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  Florida  New York
# 0   165349.20       136897.80        471784.10  192261.83        0         1
# 1   162597.70       151377.59        443898.53  191792.06        0         0
# 2   153441.51       101145.55        407934.54  191050.39        1         0
# 3   144372.41       118671.85        383199.62  182901.99        0         1
# 4   142107.34        91391.77        366168.42  166187.94        1         0
# 5   131876.90        99814.71        362861.36  156991.12        0         1
# 6   134615.46       147198.87        127716.82  156122.51        0         0
# 7   130298.13       145530.06        323876.68  155752.60        1         0
# 8   120542.52       148718.95        311613.29  152211.77        0         1
# 9   123334.88       108679.17        304981.62  149759.96        0         0
# 10  101913.08       110594.11        229160.95  146121.95        1         0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scal=StandardScaler()

# %%
ddf.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit', 'Florida',
#        'New York'],
#       dtype='object')

# %%
da=scal.fit_transform(ddf[['R&D Spend','Administration', 'Marketing Spend']])

# %%
da=pd.DataFrame(da)

# %%
da
# Out:
#            0         1         2
# 0   2.016411  0.560753  2.153943
# 1   1.955860  1.082807  1.923600
# 2   1.754364 -0.728257  1.626528
# 3   1.554784 -0.096365  1.422210
# 4   1.504937 -1.079919  1.281528
# 5   1.279800 -0.776239  1.254210
# 6   1.340066  0.932147 -0.688150
# 7   1.245057  0.871980  0.932186
# 8   1.030369  0.986952  0.830887
# 9   1.091819 -0.456640  0.776107
# 10  0.620398 -0.387599  0.149807
# 11  0.593085 -1.065540  0.319834
# 12  0.443260  0.215449  0.320617
# 13  0.402078  0.510179  0.343957
# 14  1.017181  1.269199  0.375742
# 15  0.897913  0.045868  0.419219
# 16  0.094441  0.009118  0.440446
# 17  0.460720  0.855666  0.591017
# 18  0.396725 -0.258465  0.692992
# 19  0.279442  1.159837 -1.743127
# 20  0.055726 -0.269588  0.723926
# 21  0.102724  1.169186  0.732788
# 22  0.006007  0.051850  0.762376
# 23 -0.136201 -0.562211  0.774349
# 24  0.073115 -0.795469 -0.581939
# 25 -0.199312  0.656489 -0.603517
# 26  0.035370  0.821718 -0.635835
# ...

# %%
enc=pd.concat([da,dat],axis=1)

# %%
enc
# Out:
#            0         1         2  Florida  New York
# 0   2.016411  0.560753  2.153943        0         1
# 1   1.955860  1.082807  1.923600        0         0
# 2   1.754364 -0.728257  1.626528        1         0
# 3   1.554784 -0.096365  1.422210        0         1
# 4   1.504937 -1.079919  1.281528        1         0
# 5   1.279800 -0.776239  1.254210        0         1
# 6   1.340066  0.932147 -0.688150        0         0
# 7   1.245057  0.871980  0.932186        1         0
# 8   1.030369  0.986952  0.830887        0         1
# 9   1.091819 -0.456640  0.776107        0         0
# 10  0.620398 -0.387599  0.149807        1         0
# 11  0.593085 -1.065540  0.319834        0         0
# 12  0.443260  0.215449  0.320617        1         0
# 13  0.402078  0.510179  0.343957        0         0
# 14  1.017181  1.269199  0.375742        1         0
# 15  0.897913  0.045868  0.419219        0         1
# 16  0.094441  0.009118  0.440446        0         0
# ...

# %%
YY=ddf['Profit']

# %%
YY = YY.values.reshape(50,)

# %%
YY
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
encd=enc.iloc[:,:].values

# %%
encd
# Out:
# array([[ 2.01641149e+00,  5.60752915e-01,  2.15394309e+00,
#          0.00000000e+00,  1.00000000e+00],
#        [ 1.95586034e+00,  1.08280658e+00,  1.92360040e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.75436374e+00, -7.28257028e-01,  1.62652767e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 1.55478369e+00, -9.63646307e-02,  1.42221024e+00,
#          0.00000000e+00,  1.00000000e+00],
#        [ 1.50493720e+00, -1.07991935e+00,  1.28152771e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 1.27980001e+00, -7.76239071e-01,  1.25421046e+00,
#          0.00000000e+00,  1.00000000e+00],
#        [ 1.34006641e+00,  9.32147208e-01, -6.88149930e-01,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.24505666e+00,  8.71980011e-01,  9.32185978e-01,
#          1.00000000e+00,  0.00000000e+00],
#        [ 1.03036886e+00,  9.86952101e-01,  8.30886909e-01,
#          0.00000000e+00,  1.00000000e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
models=LinearRegression()

# %%
X=encd
Y=YY

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (35, 5)
# (15, 5)
# (35,)
# (15,)

# %%
models.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=models.predict(x_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9233365601325952

# %%
plt.plot(y_test,color='g')
plt.plot(y_pred,color='r')
