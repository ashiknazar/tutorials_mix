# %%
import pandas as pd
import seaborn as sns
data=pd.read_csv('titanic.csv')
data.head()

# %%
sns.distplot(data['Age'].dropna())
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1612\4017976669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'].dropna())   #droping the null values , itt looks like a normal distrribution
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
#creating outlier
sns.distplot(data['Age'].fillna(100))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1612\3581777754.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'].fillna(100))
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
figure=data.boxplot(column="Age")

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
uppper_boundary=data['Age'].mean() + 3* data['Age'].std()   #right
lower_boundary=data['Age'].mean() - 3* data['Age'].std()   #left
print(lower_boundary), print(uppper_boundary),print(data['Age'].mean())
# Out:
# -13.880374349943303
# 73.27860964406094
# 29.69911764705882
# (None, None, None)

# %%
data.boxplot(column="Fare")
# Out:
# <AxesSubplot: >

# %%
data['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
IQR=data.Fare.quantile(0.75)-data.Fare.quantile(0.25)
IQR
# Out:
# 23.0896

# %%
lower_bridge=data['Fare'].quantile(0.25)-(IQR*1.5)
upper_bridge=data['Fare'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# -26.724
# 65.6344
# (None, None)

# %%
data1=data.copy()

# %%
data1.loc[data1['Age']>=73,'Age']=73   
data1.loc[data1['Fare']>=100,'Fare']=100

# %%
sns.histplot(data1['Age'], bins=range(0, 101, 10), kde=True, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

# Display the plot
plt.show()

# %%
sns.histplot(data1['Fare'], bins=range(0, 101, 10), kde=True, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

# Display the plot
plt.show()

# %%
data1['Age'].describe()
# Out:
# count    714.000000
# mean      29.687913
# std       14.490589
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       73.000000
# Name: Age, dtype: float64

# %%
data1['Fare'].describe()
# Out:
# count    891.000000
# mean      27.027169
# std       27.296632
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      100.000000
# Name: Fare, dtype: float64

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1['Age'].describe()
# Out:
# count    714.000000
# mean      29.687913
# std       14.490589
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       73.000000
# Name: Age, dtype: float64

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data1['Fare'].describe()
# Out:
# count    891.000000
# mean      27.027169
# std       27.296632
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      100.000000
# Name: Fare, dtype: float64
