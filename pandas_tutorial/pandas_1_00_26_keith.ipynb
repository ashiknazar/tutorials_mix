# %% [markdown]
# <li>flexibility of python</li>
# <li>work with big data</li>

# %%
import pandas as pd
data=pd.read_csv('pokemon.csv')

# %%
pd.get_option('display.max_columns')
pd.set_option('display.max_columns', 50)

# %%
data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  against_grass  against_ground  against_ice  \
# ...

# %%
list(data.columns.values)
# Out:
# ['abilities',
#  'against_bug',
#  'against_dark',
#  'against_dragon',
#  'against_electric',
#  'against_fairy',
#  'against_fight',
#  'against_fire',
#  'against_flying',
#  'against_ghost',
#  'against_grass',
#  'against_ground',
#  'against_ice',
#  'against_normal',
#  'against_poison',
#  'against_psychic',
#  'against_rock',
#  'against_steel',
#  'against_water',
#  'attack',
#  'base_egg_steps',
#  'base_happiness',
#  'base_total',
#  'capture_rate',
#  'classfication',
#  'defense',
#  'experience_growth',
#  'height_m',
#  'hp',
#  'japanese_name',
#  'name',
#  'percentage_male',
#  'pokedex_number',
#  'sp_attack',
#  'sp_defense',
#  'speed',
#  'type1',
#  'type2',
#  'weight_kg',
#  'generation',
#  'is_legendary']

# %%
data.name
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
data['name']
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
type(data['name'][0:5])
# Out:
# pandas.core.series.Series

# %%
data[['name','abilities','generation']]
# Out:
#            name                    abilities  generation
# 0     Bulbasaur  ['Overgrow', 'Chlorophyll']           1
# 1       Ivysaur  ['Overgrow', 'Chlorophyll']           1
# 2      Venusaur  ['Overgrow', 'Chlorophyll']           1
# 3    Charmander     ['Blaze', 'Solar Power']           1
# 4    Charmeleon     ['Blaze', 'Solar Power']           1
# ..          ...                          ...         ...
# 796  Celesteela              ['Beast Boost']           7
# 797     Kartana              ['Beast Boost']           7
# 798    Guzzlord              ['Beast Boost']           7
# 799    Necrozma              ['Prism Armor']           7
# 800    Magearna               ['Soul-Heart']           7
#
# [801 rows x 3 columns]

# %%
data.iloc[1,0]
# Out:
# "['Overgrow', 'Chlorophyll']"

# %%
data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  against_grass  against_ground  against_ice  \
# ...

# %%
df=pd.DataFrame({"ashik":[1,2,3,4],"amal":[5,6,7,8]})

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    ashik  amal
# 0      1     5
# 1      2     6
# 2      3     7
# 3      4     8

# %%
data['type1']
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 796      steel
# 797      grass
# 798       dark
# 799    psychic
# 800      steel
# Name: type1, Length: 801, dtype: object

# %%
data.loc[data['type1']=='fire']
# Out:
#                                              abilities  against_bug  \
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 36   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 37   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 57           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 58           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 76            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 77            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 125                     ['Flame Body', 'Vital Spirit']         0.50
# 135                             ['Flash Fire', 'Guts']         0.50
# 145                         ['Pressure', 'Flame Body']         0.25
# 154                            ['Blaze', 'Flash Fire']         0.50
# ...

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  against_grass  against_ground  against_ice  \
# ...

# %%
data.loc[data['classfication'].str.contains('Seed')]
# Out:
#                                         abilities  against_bug  against_dark  \
# 0                     ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1                     ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2                     ['Overgrow', 'Chlorophyll']          1.0           1.0
# 190  ['Chlorophyll', 'Solar Power', 'Early Bird']          2.0           1.0
# 596                                ['Iron Barbs']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 0               1.0               0.5            0.5            0.5
# 1               1.0               0.5            0.5            0.5
# 2               1.0               0.5            0.5            0.5
# 190             1.0               0.5            1.0            1.0
# 596             0.5               0.5            0.5            2.0
#
#      against_fire  against_flying  against_ghost  against_grass  \
# ...

# %% [raw]
# data=pd.read_excel('pok.xlsx')
# data=pd.read_csv('pok.txt',delimiter='\t')

# %%
print(data.columns)

# %%
data['name']

# %%
data['name'][0:4]

# %%
 data.name[0:4]

# %%
print(data[['name','type1']])

# %%
#data.iloc[1] #first row
data.iloc[1:4] #no of row

# %%
data.iloc[1,30]

# %%
data['total']=data.iloc[:,1:20].sum(axis=1)

# %%
data.iloc[:,1:20]

# %%
for index,row in data.iterrows():
    print(index,row['name'])

# %%
#data.loc[1]
data.loc[1:4]

# %%
data.loc[data['type1']=='fire']

# %%
data.sort_values('name') #ascending=False

# %%
data.sort_values(['name','type1'],ascending=[1,0])

# %%
data.columns

# %%
data['total']=data['hp']+data['attack']

# %%
data

# %%
data=data.drop(columns=['total'])

# %%
data.columns

# %%
data.drop(columns=['against_bug', 'against_dark', 'against_dragon',
       'against_electric', 'against_fairy', 'against_fight', 'against_fire',
       'against_flying', 'against_ghost', 'against_grass', 'against_ground',
       'against_ice', 'against_normal', 'against_poison', 'against_psychic',
       'against_rock', 'against_steel', 'against_water', 'attack'],inplace=True)

# %%
data

# %%
datas=data[['total','name','type1','abilities','hp','weight_kg','is_legendary','type2']]

# %%
datas.sort_values('total',ascending=False)

# %%
datas.to_csv('modified.csv',index=False)
#datas.to_excel('mod.xlsx',index=False)
#datas.to_csv('mod.txt',index=False,sep='\t')

# %%
datas=pd.read_csv('modified.csv')

# %%
datas.head()

# %% [markdown]
# ## filtering data

# %%
datas.head()

# %%
datas.loc[datas['type1']=='fire']

# %%
#new_df.reset_index()
#new_df.reset_index(drop=True)
#new_df.reset_index(drop=True,inplace=True)

# %%
datas.loc[datas['name'].str.contains('Mega')]

#datas.loc[~datas['name'].str.contains('Mega')]

# %%
import re

# %%
datas.loc[datas['type1'].str.contains('fire|grass',regex=True)]

# %%
datas.loc[datas['type1'].str.contains('Fire|Grass',flags=re.I,regex=True)]

# %%
datas.loc[datas['name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]

# %% [markdown]
# ### conditional changes

# %%
datas.loc[datas['type1']=='fire','type1']='Flamer'

# %%
datas.head()

# %%
datas.loc[datas['type1']=='Flamer','type1']='fire'

# %%
datas

# %%
datas.loc[datas['total']>100,['new_col','new_col1']]='test'

# %%
datas.loc[datas['total']>100,['new_col','new_col1']]=['test','test1']

# %%
datas

# %% [markdown]
# #### agregate statistics(groupby)

# %%
datas.groupby(['type1']).mean(numeric_only=True)
datas.groupby(['type1']).mean(numeric_only=True).sort_values('is_legendary',ascending=False)
datas.groupby(['type1']).mean(numeric_only=True)
datas.groupby(['type1']).count()

# %%
datas.groupby(['type1']).count()['name']
datas.groupby(['type1','type2']).count()['name']

# %%
df=pd.read_csv('modified.csv',chunksize=5)
df=pd.read_csv('modified.csv')

# %%
type(df)

# %%
for dd in pd.read_csv('modified.csv',chunksize=5):
    print("chunks      .:")
    print(dd)

# %%
new_df=pd.DataFrame(columns=df.columns)

# %%
for df in pd.read_csv('modified.csv',chunksize=5):
    res=df.groupby(['type1']).count()
    new_df=pd.concat([new_df,res])

# %%
new_df
