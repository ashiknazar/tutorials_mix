# %%
import pandas as pd
import numpy as np

# %%
info=np.array([3,4,3,4,7,90])
pp=pd.Series(info)

# %%
type(pp)
# Out:
# pandas.core.series.Series

# %%
fram=['pyth','c','java']
df=pd.DataFrame(fram)

# %%
df
# Out:
#       0
# 0  pyth
# 1     c
# 2  java

# %%
dictt={'nam':['aj','am','ab'],'age':[20,30,22]}
dictt=pd.DataFrame(dictt)

# %%
dictt
# Out:
#   nam  age
# 0  aj   20
# 1  am   30
# 2  ab   22

# %%
dictt['age']
# Out:
# 0    20
# 1    30
# 2    22
# Name: age, dtype: int64

# %%
dictt.pop('age')
# Out:
# 0    20
# 1    30
# 2    22
# Name: age, dtype: int64

# %%
dictt
# Out:
#   nam
# 0  aj
# 1  am
# 2  ab

# %%
del dictt['nam']

dictt.shape

# %%
df=pd.read_csv('parks.csv')

# %%
df.shape
# Out:
# (56, 6)

# %%
df.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
df.tail(5)
# Out:
#    Park Code                                       Park Name       State  \
# 51      WICA                         Wind Cave National Park          SD
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
# 54      YOSE                          Yosemite National Park          CA
# 55      ZION                              Zion National Park          UT
#
#       Acres  Latitude  Longitude
# 51    28295     43.57    -103.48
# 52  8323148     61.00    -142.00
# 53  2219791     44.60    -110.50
# 54   761266     37.83    -119.50
# 55   146598     37.30    -113.05

# %%
df.describe()
# Out:
#               Acres   Latitude   Longitude
# count  5.600000e+01  56.000000   56.000000
# mean   9.279291e+05  41.233929 -113.234821
# std    1.709258e+06  10.908831   22.440287
# min    5.550000e+03  19.380000 -159.280000
# 25%    6.901050e+04  35.527500 -121.570000
# 50%    2.387645e+05  38.550000 -110.985000
# 75%    8.173602e+05  46.880000 -103.400000
# max    8.323148e+06  67.780000  -68.210000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Code  56 non-null     object
#  1   Park Name  56 non-null     object
#  2   State      56 non-null     object
#  3   Acres      56 non-null     int64
#  4   Latitude   56 non-null     float64
#  5   Longitude  56 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.8+ KB

# %%
df.columns
# Out:
# Index(['Park Code', 'Park Name', 'State', 'Acres', 'Latitude', 'Longitude'], dtype='object')

# %%
df.columns.values
# Out:
# array(['Park Code', 'Park Name', 'State', 'Acres', 'Latitude',
#        'Longitude'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 27

# %%
df['State'].value_counts()
# Out:
# AK            8
# CA            7
# UT            5
# CO            4
# FL            3
# AZ            3
# WA            3
# SD            2
# TX            2
# HI            2
# ME            1
# MI            1
# ND            1
# KY            1
# VA            1
# MN            1
# AR            1
# MT            1
# WY            1
# TN, NC        1
# NV            1
# CA, NV        1
# OH            1
# OR            1
# SC            1
# NM            1
# WY, MT, ID    1
# Name: State, dtype: int64

# %%
df.isnull()
# Out:
#     Park Code  Park Name  State  Acres  Latitude  Longitude
# 0       False      False  False  False     False      False
# 1       False      False  False  False     False      False
# 2       False      False  False  False     False      False
# 3       False      False  False  False     False      False
# 4       False      False  False  False     False      False
# 5       False      False  False  False     False      False
# 6       False      False  False  False     False      False
# 7       False      False  False  False     False      False
# 8       False      False  False  False     False      False
# 9       False      False  False  False     False      False
# 10      False      False  False  False     False      False
# 11      False      False  False  False     False      False
# 12      False      False  False  False     False      False
# 13      False      False  False  False     False      False
# 14      False      False  False  False     False      False
# ...

# %%
df.isnull().sum()
# Out:
# Park Code    0
# Park Name    0
# State        0
# Acres        0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
df.drop(['Latitude'],axis=1)
df
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# ...

# %%
df.drop(['Latitude'],axis=1,inplace=True)
df
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# ...

# %%
df['Park Name'].str.contains('Lake')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# Name: Park Name, dtype: bool

# %%
len(df['Park Name'].str.contains('Lake'))
# Out:
# 56

# %%
df['Park Name'].str.contains('Lake').sum()
# Out:
# 2

# %%
df['Park Name'].str.contains('Lake').value_counts()
# Out:
# False    54
# True      2
# Name: Park Name, dtype: int64

# %%
df['State'].value_counts()
# Out:
# AK            8
# CA            7
# UT            5
# CO            4
# FL            3
# AZ            3
# WA            3
# SD            2
# TX            2
# HI            2
# ME            1
# MI            1
# ND            1
# KY            1
# VA            1
# MN            1
# AR            1
# MT            1
# WY            1
# TN, NC        1
# NV            1
# CA, NV        1
# OH            1
# OR            1
# SC            1
# NM            1
# WY, MT, ID    1
# Name: State, dtype: int64

# %%
df['State']=='UT'
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55     True
# Name: State, dtype: bool

# %%
df[df['State']=='UT']
# Out:
#    Park Code                   Park Name State   Acres  Longitude
# 1       ARCH        Arches National Park    UT   76519    -109.57
# 6       BRCA  Bryce Canyon National Park    UT   35835    -112.18
# 7       CANY   Canyonlands National Park    UT  337598    -109.93
# 8       CARE  Capitol Reef National Park    UT  241904    -111.17
# 55      ZION          Zion National Park    UT  146598    -113.05

# %%
df.groupby('State')['Acres'].mean()
# Out:
# State
# AK            3.894906e+06
# AR            5.550000e+03
# AZ            4.674587e+05
# CA            4.160020e+05
# CA, NV        4.740912e+06
# CO            9.847100e+04
# FL            5.820543e+05
# HI            1.762625e+05
# KY            5.283000e+04
# ME            4.739000e+04
# MI            5.717900e+05
# MN            2.182000e+05
# MT            1.013572e+06
# ND            7.044700e+04
# NM            4.676600e+04
# NV            7.718000e+04
# OH            3.295000e+04
# OR            1.832240e+05
# SC            2.654600e+04
# SD            1.355255e+05
# TN, NC        5.214900e+05
# TX            4.437895e+05
# UT            1.676908e+05
# VA            1.990450e+05
# WA            5.543523e+05
# WY            3.099950e+05
# WY, MT, ID    2.219791e+06
# Name: Acres, dtype: float64

# %%
data=df.drop([0,1,2,3],axis=0)
data
# Out:
#    Park Code                                       Park Name       State  \
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# 12      CRLA                       Crater Lake National Park          OR
# 13      CUVA                   Cuyahoga Valley National Park          OH
# 14      DENA               Denali National Park and Preserve          AK
# 15      DEVA                      Death Valley National Park      CA, NV
# ...

# %%
df
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# ...

# %%
dat=pd.read_csv('Ecommerce_Purchases')

# %%
dat.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
dat.shape
# Out:
# (10000, 14)

# %%
dat.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
dat['Purchase Price'].mean()
# Out:
# 50.347302

# %%
dat['Purchase Price'].max()
# Out:
# 99.99

# %%
dat['Purchase Price'].min()
# Out:
# 0.0

# %%
dat['Language'].str.contains('en').sum()
# Out:
# 1098

# %%
len(dat[dat['Job']=="Lawyer"])
# Out:
# 30

# %%
dat['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
dat['Job'].value_counts().head()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %%
data=dat[dat['Lot']=="90 WT"]

data['Purchase Price']

# %%
da=dat[dat['Credit Card']==4926535242672853]

da['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
dat['CC Exp Date'].str.contains("/25").sum()
# Out:
# 1033

# %%
dat['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
da=dat[(dat['CC Provider']=="American Express") ]
daa =da.loc[dat['Purchase Price'] > 95]

# %% [markdown]
# C:\Users\user\AppData\Local\Temp\ipykernel_1936\1745146284.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   daa=da[dat['Purchase Price']>95]

# %%
len(daa)
# Out:
# 39

# %%
daa.shape
# Out:
# (39, 14)

# %%
#error
daat =dat.loc[(dat['Purchase Price'] > 95) and (dat['CC Provider']=="American Express")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 daat =dat.loc[(dat['Purchase Price'] > 95) and (dat['CC Provider']=="American Express")]
#
# File ~\anaconda3\envs\tf-2\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
daat = dat.loc[(dat['Purchase Price'] > 95) & (dat['CC Provider'] == "American Express")]
len(daat)
# Out:
# 39

# %%
dat['Email'].value_counts().head()
# Out:
# leekathy@yahoo.com         2
# joshua41@hotmail.com       2
# christopher29@gmail.com    2
# ethomas@hotmail.com        2
# brownjohn@hotmail.com      2
# Name: Email, dtype: int64

# %%
dff = dat['Email'].str.split('@').str[1]
domain_counts = dff.value_counts()
domain_counts.head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
