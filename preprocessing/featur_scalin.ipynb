# %%
data=[[2,4],[6,7],[12,33]]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scal=MinMaxScaler()

# %%
scal.fit_transform(data)
# Out:
# array([[0.        , 0.        ],
#        [0.4       , 0.10344828],
#        [1.        , 1.        ]])

# %%
mns=MinMaxScaler(feature_range=(-2,2))
mns.fit_transform(data)
# Out:
# array([[-2.       , -2.       ],
#        [-0.4      , -1.5862069],
#        [ 2.       ,  2.       ]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()
std.fit_transform(data)
# Out:
# array([[-1.13554995, -0.8191675 ],
#        [-0.16222142, -0.58877664],
#        [ 1.29777137,  1.40794413]])

# %%
import pandas as pd

# %%
dat=pd.read_csv('CARSS.csv')

# %%
dat.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo     1.0     790   99
# 1  Mitsubishi  Space Star     1.2    1160   95
# 2       Skoda      Citigo     1.0     929   95
# 3        Fiat         500     0.9     865   90
# 4        Mini      Cooper     1.5    1140  105

# %%
from sklearn.preprocessing import StandardScaler

std=StandardScaler()

ds=std.fit_transform(dat[[ 'Volume','Weight']])

ds=pd.DataFrame(ds)

ds.columns = ['volume', 'weight']

df=pd.concat([dat,ds],axis=1)

# %%
df
# Out:
#            Car       Model  Volume  Weight  CO2    volume    weight
# 0       Toyoty        Aygo     1.0     790   99 -1.593366 -2.103893
# 1   Mitsubishi  Space Star     1.2    1160   95 -1.071901 -0.554072
# 2        Skoda      Citigo     1.0     929   95 -1.593366 -1.521663
# 3         Fiat         500     0.9     865   90 -1.854099 -1.789740
# 4         Mini      Cooper     1.5    1140  105 -0.289703 -0.637846
# 5           VW         Up!     1.0     929  105 -1.593366 -1.521663
# 6        Skoda       Fabia     1.4    1109   90 -0.550436 -0.767696
# 7     Mercedes     A-Class     1.5    1365   92 -0.289703  0.304612
# 8         Ford      Fiesta     1.5    1112   98 -0.289703 -0.755130
# 9         Audi          A1     1.6    1150   99 -0.028970 -0.595959
# 10     Hyundai         I20     1.1     980   99 -1.332634 -1.308039
# 11      Suzuki       Swift     1.3     990  101 -0.811168 -1.266152
# 12        Ford      Fiesta     1.0    1112   99 -1.593366 -0.755130
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mnx=MinMaxScaler()

da=std.fit_transform(dat[[ 'Volume','Weight']])

da=pd.DataFrame(da)

da.columns = ['Volume_minmax', 'Weight_minmax']

df=pd.concat([dat,da],axis=1)

# %%
df
# Out:
#            Car       Model  Volume  Weight  CO2  Volume_minmax  Weight_minmax
# 0       Toyoty        Aygo     1.0     790   99      -1.593366      -2.103893
# 1   Mitsubishi  Space Star     1.2    1160   95      -1.071901      -0.554072
# 2        Skoda      Citigo     1.0     929   95      -1.593366      -1.521663
# 3         Fiat         500     0.9     865   90      -1.854099      -1.789740
# 4         Mini      Cooper     1.5    1140  105      -0.289703      -0.637846
# 5           VW         Up!     1.0     929  105      -1.593366      -1.521663
# 6        Skoda       Fabia     1.4    1109   90      -0.550436      -0.767696
# 7     Mercedes     A-Class     1.5    1365   92      -0.289703       0.304612
# 8         Ford      Fiesta     1.5    1112   98      -0.289703      -0.755130
# 9         Audi          A1     1.6    1150   99      -0.028970      -0.595959
# 10     Hyundai         I20     1.1     980   99      -1.332634      -1.308039
# ...

# %%
import seaborn as sns

# %%
ds = sns.load_dataset('iris')

ds.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
mean_values = ds.mean(numeric_only=True)

# %%
mean_values
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

std=StandardScaler()

dsa=std.fit_transform(ds[[ 'sepal_length','sepal_width','petal_length','petal_width']])

dss=pd.DataFrame(dsa)

dss.columns = ['sepal_length_std','sepal_width_std','petal_length_std','petal_width_std']

df=pd.concat([ds,dss],axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_std  sepal_width_std  petal_length_std  petal_width_std
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

mnx=MinMaxScaler()

dsa=mnx.fit_transform(ds[[ 'sepal_length','sepal_width','petal_length','petal_width']])

dss=pd.DataFrame(dsa)

dss.columns = ['sepal_length_mnx','sepal_width_mnx','petal_length_mnx','petal_width_mnx']

df=pd.concat([ds,dss],axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_mnx  sepal_width_mnx  petal_length_mnx  petal_width_mnx
# ...

# %%
import seaborn as sns

# List all available datasets in Seaborn
available_datasets = sns.get_dataset_names()
print(available_datasets)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
ds = sns.load_dataset('brain_networks')
ds.tail()
# Out:
#     network                    1                  1.1                   2  \
# 918     915  -7.4295125007629395    -4.81321907043457  -3.670536518096924
# 919     916   -33.55413818359375   -38.60562133789063  -25.66480255126953
# 920     917   -78.53956604003906   -74.19718933105469  -54.04159545898438
# 921     918  -103.23582458496094    -98.7442855834961  -40.10954284667969
# 922     919   -36.28886795043945  -10.762069702148438  -30.35626220703125
#
#                      2.1                    3                  3.1  \
# 918   1.4422610998153689    -19.6804313659668  -29.109355926513672
# 919  -30.252351760864254   5.5627851486206055   20.182186126708984
# 920   -39.97029113769531  -14.277058601379395  -30.606460571289066
# 921   -44.90773391723633   12.109148025512695   1.6213401556015017
# 922   -23.31950378417969   14.252187728881836   -27.55986022949219
#
#                        4                  4.1                     5  ...  \
# ...
