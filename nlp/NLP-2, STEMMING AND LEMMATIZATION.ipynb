# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\91799\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\91799\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\91799\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91799\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\91799\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\91799\anaconda3\lib\site-packages (from click->nltk) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')   #Another way to download
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91799\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
paragraph="""I have three visions for India. In 3000 years of our history, people from all over 
               the world have come and invaded us, captured our lands, conquered our minds. 
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours. 
               Yet we have not done this to any other nation. We have not conquered anyone. 
               We have not grabbed their land, their culture, 
               their history and tried to enforce our way of life on them. 
               Why? Because we respect the freedom of others.That is why my 
               first vision is that of freedom. I believe that India got its first vision of 
               this in 1857, when we started the War of Independence. It is this freedom that
               we must protect and nurture and build on. If we are not free, no one will respect us.
               My second vision for India’s development. For fifty years we have been a developing nation.
               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world
               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.
               Our achievements are being globally recognised today. Yet we lack the self-confidence to
               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?
               I have a third vision. India must stand up to the world. Because I believe that unless India 
               stands up to the world, no one will respect us. Only strength respects strength. We must be 
               strong not only as a military power but also as an economic power. Both must go hand-in-hand. 
               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of 
               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.
               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life. 
               I see four milestones in my career"""

# %%
#tokenizing sentences

sentences=nltk.sent_tokenize(paragraph)
sentences
# Out:
# ['I have three visions for India.',
#  'In 3000 years of our history, people from all over \n               the world have come and invaded us, captured our lands, conquered our minds.',
#  'From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,\n               the French, the Dutch, all of them came and looted us, took over what was ours.',
#  'Yet we have not done this to any other nation.',
#  'We have not conquered anyone.',
#  'We have not grabbed their land, their culture, \n               their history and tried to enforce our way of life on them.',
#  'Why?',
#  'Because we respect the freedom of others.That is why my \n               first vision is that of freedom.',
#  'I believe that India got its first vision of \n               this in 1857, when we started the War of Independence.',
#  'It is this freedom that\n               we must protect and nurture and build on.',
#  'If we are not free, no one will respect us.',
#  'My second vision for India’s development.',
#  'For fifty years we have been a developing nation.',
#  'It is time we see ourselves as a developed nation.',
#  'We are among the top 5 nations of the world\n               in terms of GDP.',
#  'We have a 10 percent growth rate in most areas.',
#  'Our poverty levels are falling.',
#  'Our achievements are being globally recognised today.',
#  'Yet we lack the self-confidence to\n               see ourselves as a developed nation, self-reliant and self-assured.',
#  'Isn’t this incorrect?',
#  'I have a third vision.',
#  'India must stand up to the world.',
#  'Because I believe that unless India \n               stands up to the world, no one will respect us.',
#  'Only strength respects strength.',
#  'We must be \n               strong not only as a military power but also as an economic power.',
#  'Both must go hand-in-hand.',
#  'My good fortune was to have worked with three great minds.',
#  'Dr. Vikram Sarabhai of the Dept.',
#  'of \n               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.',
#  'I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.',
#  'I see four milestones in my career']

# %%
#tokenizing words
words=nltk.word_tokenize(paragraph)
words
# Out:
# ['I',
#  'have',
#  'three',
#  'visions',
#  'for',
#  'India',
#  '.',
#  'In',
#  '3000',
#  'years',
#  'of',
#  'our',
#  'history',
#  ',',
#  'people',
#  'from',
#  'all',
#  'over',
#  'the',
#  'world',
#  'have',
#  'come',
#  'and',
#  'invaded',
#  'us',
#  ',',
#  'captured',
#  'our',
#  'lands',
#  ',',
#  'conquered',
#  'our',
#  'minds',
#  '.',
#  'From',
#  'Alexander',
#  'onwards',
#  ',',
#  'the',
#  'Greeks',
#  ',',
#  'the',
#  'Turks',
#  ',',
#  'the',
#  'Moguls',
#  ',',
#  'the',
#  'Portuguese',
#  ',',
#  'the',
#  'British',
#  ',',
#  'the',
#  'French',
#  ',',
#  'the',
#  'Dutch',
#  ',',
#  'all',
#  'of',
#  'them',
#  'came',
#  'and',
#  'looted',
#  'us',
#  ',',
#  'took',
#  'over',
#  'what',
#  'was',
#  'ours',
#  '.',
#  'Yet',
#  'we',
#  'have',
#  'not',
#  'done',
#  'this',
#  'to',
#  'any',
#  'other',
#  'nation',
#  '.',
#  'We',
#  'have',
#  'not',
#  'conquered',
#  'anyone',
#  '.',
#  'We',
#  'have',
#  'not',
#  'grabbed',
#  'their',
#  'land',
#  ',',
#  'their',
#  'culture',
#  ',',
#  'their',
#  'history',
#  'and',
#  'tried',
#  'to',
#  'enforce',
#  'our',
#  'way',
#  'of',
#  'life',
#  'on',
#  'them',
#  '.',
#  'Why',
#  '?',
#  'Because',
#  'we',
#  'respect',
#  'the',
#  'freedom',
#  'of',
#  'others.That',
#  'is',
#  'why',
#  'my',
#  'first',
#  'vision',
#  'is',
#  'that',
#  'of',
#  'freedom',
#  '.',
#  'I',
#  'believe',
#  'that',
#  'India',
#  'got',
#  'its',
#  'first',
#  'vision',
#  'of',
#  'this',
#  'in',
#  '1857',
#  ',',
#  'when',
#  'we',
#  'started',
#  'the',
#  'War',
#  'of',
#  'Independence',
#  '.',
#  'It',
#  'is',
#  'this',
#  'freedom',
#  'that',
#  'we',
#  'must',
#  'protect',
#  'and',
#  'nurture',
#  'and',
#  'build',
#  'on',
#  '.',
#  'If',
#  'we',
#  'are',
#  'not',
#  'free',
#  ',',
#  'no',
#  'one',
#  'will',
#  'respect',
#  'us',
#  '.',
#  'My',
#  'second',
#  'vision',
#  'for',
#  'India',
#  '’',
#  's',
#  'development',
#  '.',
#  'For',
#  'fifty',
#  'years',
#  'we',
#  'have',
#  'been',
#  'a',
#  'developing',
#  'nation',
#  '.',
#  'It',
#  'is',
#  'time',
#  'we',
#  'see',
#  'ourselves',
#  'as',
#  'a',
#  'developed',
#  'nation',
#  '.',
#  'We',
#  'are',
#  'among',
#  'the',
#  'top',
#  '5',
#  'nations',
#  'of',
#  'the',
#  'world',
#  'in',
#  'terms',
#  'of',
#  'GDP',
#  '.',
#  'We',
#  'have',
#  'a',
#  '10',
#  'percent',
#  'growth',
#  'rate',
#  'in',
#  'most',
#  'areas',
#  '.',
#  'Our',
#  'poverty',
#  'levels',
#  'are',
#  'falling',
#  '.',
#  'Our',
#  'achievements',
#  'are',
#  'being',
#  'globally',
#  'recognised',
#  'today',
#  '.',
#  'Yet',
#  'we',
#  'lack',
#  'the',
#  'self-confidence',
#  'to',
#  'see',
#  'ourselves',
#  'as',
#  'a',
#  'developed',
#  'nation',
#  ',',
#  'self-reliant',
#  'and',
#  'self-assured',
#  '.',
#  'Isn',
#  '’',
#  't',
#  'this',
#  'incorrect',
#  '?',
#  'I',
#  'have',
#  'a',
#  'third',
#  'vision',
#  '.',
#  'India',
#  'must',
#  'stand',
#  'up',
#  'to',
#  'the',
#  'world',
#  '.',
#  'Because',
#  'I',
#  'believe',
#  'that',
#  'unless',
#  'India',
#  'stands',
#  'up',
#  'to',
#  'the',
#  'world',
#  ',',
#  'no',
#  'one',
#  'will',
#  'respect',
#  'us',
#  '.',
#  'Only',
#  'strength',
#  'respects',
#  'strength',
#  '.',
#  'We',
#  'must',
#  'be',
#  'strong',
#  'not',
#  'only',
#  'as',
#  'a',
#  'military',
#  'power',
#  'but',
#  'also',
#  'as',
#  'an',
#  'economic',
#  'power',
#  '.',
#  'Both',
#  'must',
#  'go',
#  'hand-in-hand',
#  '.',
#  'My',
#  'good',
#  'fortune',
#  'was',
#  'to',
#  'have',
#  'worked',
#  'with',
#  'three',
#  'great',
#  'minds',
#  '.',
#  'Dr.',
#  'Vikram',
#  'Sarabhai',
#  'of',
#  'the',
#  'Dept',
#  '.',
#  'of',
#  'space',
#  ',',
#  'Professor',
#  'Satish',
#  'Dhawan',
#  ',',
#  'who',
#  'succeeded',
#  'him',
#  'and',
#  'Dr.',
#  'Brahm',
#  'Prakash',
#  ',',
#  'father',
#  'of',
#  'nuclear',
#  'material',
#  '.',
#  'I',
#  'was',
#  'lucky',
#  'to',
#  'have',
#  'worked',
#  'with',
#  'all',
#  'three',
#  'of',
#  'them',
#  'closely',
#  'and',
#  'consider',
#  'this',
#  'the',
#  'great',
#  'opportunity',
#  'of',
#  'my',
#  'life',
#  '.',
#  'I',
#  'see',
#  'four',
#  'milestones',
#  'in',
#  'my',
#  'career']

# %%
#another way

from nltk.tokenize import sent_tokenize,word_tokenize
print(sent_tokenize(paragraph))
print()
print(word_tokenize(paragraph))
# Out:
# ['I have three visions for India.', 'In 3000 years of our history, people from all over \n               the world have come and invaded us, captured our lands, conquered our minds.', 'From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,\n               the French, the Dutch, all of them came and looted us, took over what was ours.', 'Yet we have not done this to any other nation.', 'We have not conquered anyone.', 'We have not grabbed their land, their culture, \n               their history and tried to enforce our way of life on them.', 'Why?', 'Because we respect the freedom of others.That is why my \n               first vision is that of freedom.', 'I believe that India got its first vision of \n               this in 1857, when we started the War of Independence.', 'It is this freedom that\n               we must protect and nurture and build on.', 'If we are not free, no one will respect us.', 'My second vision for India’s development.', 'For fifty years we have been a developing nation.', 'It is time we see ourselves as a developed nation.', 'We are among the top 5 nations of the world\n               in terms of GDP.', 'We have a 10 percent growth rate in most areas.', 'Our poverty levels are falling.', 'Our achievements are being globally recognised today.', 'Yet we lack the self-confidence to\n               see ourselves as a developed nation, self-reliant and self-assured.', 'Isn’t this incorrect?', 'I have a third vision.', 'India must stand up to the world.', 'Because I believe that unless India \n               stands up to the world, no one will respect us.', 'Only strength respects strength.', 'We must be \n               strong not only as a military power but also as an economic power.', 'Both must go hand-in-hand.', 'My good fortune was to have worked with three great minds.', 'Dr. Vikram Sarabhai of the Dept.', 'of \n               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.', 'I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.', 'I see four milestones in my career']
# ['I', 'have', 'three', 'visions', 'for', 'India', '.', 'In', '3000', 'years', 'of', 'our', 'history', ',', 'people', 'from', 'all', 'over', 'the', 'world', 'have', 'come', 'and', 'invaded', 'us', ',', 'captured', 'our', 'lands', ',', 'conquered', 'our', 'minds', '.', 'From', 'Alexander', 'onwards', ',', 'the', 'Greeks', ',', 'the', 'Turks', ',', 'the', 'Moguls', ',', 'the', 'Portuguese', ',', 'the', 'British', ',', 'the', 'French', ',', 'the', 'Dutch', ',', 'all', 'of', 'them', 'came', 'and', 'looted', 'us', ',', 'took', 'over', 'what', 'was', 'ours', '.', 'Yet', 'we', 'have', 'not', 'done', 'this', 'to', 'any', 'other', 'nation', '.', 'We', 'have', 'not', 'conquered', 'anyone', '.', 'We', 'have', 'not', 'grabbed', 'their', 'land', ',', 'their', 'culture', ',', 'their', 'history', 'and', 'tried', 'to', 'enforce', 'our', 'way', 'of', 'life', 'on', 'them', '.', 'Why', '?', 'Because', 'we', 'respect', 'the', 'freedom', 'of', 'others.That', 'is', 'why', 'my', 'first', 'vision', 'is', 'that', 'of', 'freedom', '.', 'I', 'believe', 'that', 'India', 'got', 'its', 'first', 'vision', 'of', 'this', 'in', '1857', ',', 'when', 'we', 'started', 'the', 'War', 'of', 'Independence', '.', 'It', 'is', 'this', 'freedom', 'that', 'we', 'must', 'protect', 'and', 'nurture', 'and', 'build', 'on', '.', 'If', 'we', 'are', 'not', 'free', ',', 'no', 'one', 'will', 'respect', 'us', '.', 'My', 'second', 'vision', 'for', 'India', '’', 's', 'development', '.', 'For', 'fifty', 'years', 'we', 'have', 'been', 'a', 'developing', 'nation', '.', 'It', 'is', 'time', 'we', 'see', 'ourselves', 'as', 'a', 'developed', 'nation', '.', 'We', 'are', 'among', 'the', 'top', '5', 'nations', 'of', 'the', 'world', 'in', 'terms', 'of', 'GDP', '.', 'We', 'have', 'a', '10', 'percent', 'growth', 'rate', 'in', 'most', 'areas', '.', 'Our', 'poverty', 'levels', 'are', 'falling', '.', 'Our', 'achievements', 'are', 'being', 'globally', 'recognised', 'today', '.', 'Yet', 'we', 'lack', 'the', 'self-confidence', 'to', 'see', 'ourselves', 'as', 'a', 'developed', 'nation', ',', 'self-reliant', 'and', 'self-assured', '.', 'Isn', '’', 't', 'this', 'incorrect', '?', 'I', 'have', 'a', 'third', 'vision', '.', 'India', 'must', 'stand', 'up', 'to', 'the', 'world', '.', 'Because', 'I', 'believe', 'that', 'unless', 'India', 'stands', 'up', 'to', 'the', 'world', ',', 'no', 'one', 'will', 'respect', 'us', '.', 'Only', 'strength', 'respects', 'strength', '.', 'We', 'must', 'be', 'strong', 'not', 'only', 'as', 'a', 'military', 'power', 'but', 'also', 'as', 'an', 'economic', 'power', '.', 'Both', 'must', 'go', 'hand-in-hand', '.', 'My', 'good', 'fortune', 'was', 'to', 'have', 'worked', 'with', 'three', 'great', 'minds', '.', 'Dr.', 'Vikram', 'Sarabhai', 'of', 'the', 'Dept', '.', 'of', 'space', ',', 'Professor', 'Satish', 'Dhawan', ',', 'who', 'succeeded', 'him', 'and', 'Dr.', 'Brahm', 'Prakash', ',', 'father', 'of', 'nuclear', 'material', '.', 'I', 'was', 'lucky', 'to', 'have', 'worked', 'with', 'all', 'three', 'of', 'them', 'closely', 'and', 'consider', 'this', 'the', 'great', 'opportunity', 'of', 'my', 'life', '.', 'I', 'see', 'four', 'milestones', 'in', 'my', 'career']

# %% [markdown]
# # TreeBankword Tokenizer

# %% [raw]
# It seperates the punctuation from words

# %% [raw]
# These works by seperating the words using punctuation and spaces

# %%
text=("Let's see how it's working beautiful!s")
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(text)
# Out:
# ['Let', "'s", 'see', 'how', 'it', "'s", 'working', 'beautiful', '!', 's']

# %% [markdown]
# # PunktWord Tokenizer

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer=WordPunctTokenizer()
tokenizer.tokenize(text)
# Out:
# ['Let',
#  "'",
#  's',
#  'see',
#  'how',
#  'it',
#  "'",
#  's',
#  'working',
#  'beautiful',
#  '!',
#  's']

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
#choose some words to be stemmed
words=['program','programs','programer','programing','programers']
for w in words:
    print(w,':',ps.stem(w))     #we get only one root word
# Out:
# program : program
# programs : program
# programer : program
# programing : program
# programers : program

# %%
sentence='Programers program with programing languages'
words=word_tokenize(sentence)
for w in words:
    print(w,":",ps.stem(w))
# Out:
# Programers : program
# program : program
# with : with
# programing : program
# languages : languag

# %% [markdown]
# # Lemmatization

# %%
import nltk
nltk.download('wordnet')# wordnet is a lexical database of semantic relations between words in more than 200 languages
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91799\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
list1=['kites','babies','dogs','flying','smiling','driving','died','tried','feet']
for w in list1:
    print(w,':',ps.stem(w))     #we get only the root word
# Out:
# kites : kite
# babies : babi
# dogs : dog
# flying : fli
# smiling : smile
# driving : drive
# died : die
# tried : tri
# feet : feet

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\91799\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
wnl=WordNetLemmatizer()
list1=['kites','babies','dogs','flying','smiling','driving','died','tried','feet']
for w in list1:
    print(w,':',wnl.lemmatize(w))     #we get only the root word
# Out:
# kites : kite
# babies : baby
# dogs : dog
# flying : flying
# smiling : smiling
# driving : driving
# died : died
# tried : tried
# feet : foot

# %% [markdown]
# # Stopword_using_spacy:method 1

# %% [markdown]
# spaCy is a free, open-source library for NLP in Python. It's written in Python and is designed to build information extraction or natural language understanding systems.

# %% [raw]
# #installation : take anaconda prompt
# 1.conda install -c conda-forge spacy          -press enter wait till it runs,after that
# 2. python-m spacy download en

# %%
pip uninstall wasabi -y
# Out:
# Found existing installation: wasabi 0.10.0
# Uninstalling wasabi-0.10.0:
#   Successfully uninstalled wasabi-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wasabi==0.9.1
# Out:
# Collecting wasabi==0.9.1Note: you may need to restart the kernel to use updated packages.
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Installing collected packages: wasabi
# Successfully installed wasabi-0.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.0.15 requires pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4, but you have pydantic 1.10.2 which is incompatible.
# spacy 3.3.1 requires pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4, but you have pydantic 1.10.2 which is incompatible.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\91799\anaconda3\lib\site-packages (3.3.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (0.9.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (3.0.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (1.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (4.64.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (0.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (0.7.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (8.0.15)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (1.22.4)
# Requirement already satisfied: setuptools in c:\users\91799\anaconda3\lib\site-packages (from spacy) (61.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (1.0.3)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Using cached pydantic-1.8.2-cp39-cp39-win_amd64.whl (1.9 MB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: jinja2 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\91799\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\91799\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\91799\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\91799\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91799\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\91799\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\91799\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91799\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: colorama in c:\users\91799\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\91799\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\91799\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
# Successfully installed pydantic-1.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
print(spacy.__version__)
# Out:
# 3.3.1

# %% [markdown]
# en_core_web_sm is a small English pipeline trained on written web text (blogs, news, comments), that includes vocabulary, syntax and entities.

# %%
article='In computing, stop words are words which are filtered out before or \
after processing of natural language data (text).[1] Though "stop words" usually \
refers to the most common words in a language, there is no single universal list of \
stop words used by all natural language processing tools, and indeed not all tools \
even use such a list. Some tools specifically avoid removing these stop words to \
support phrase search.'

# %%
#spacy.cli.download("en_core_web_sm")

# %%
nlp=spacy.load('en_core_web_sm')#pre trained module for connecting words

# %%
spacy_stopwords=spacy.lang.en.stop_words.STOP_WORDS
print('Number of stop words:',len(spacy_stopwords))
print('first ten stop words:',list(spacy_stopwords)[:10])
# Out:
# Number of stop words: 326
# first ten stop words: ['‘s', 'eight', 'out', 'hence', 'however', 'another', 'top', 'without', 'herein', 'via']

# %%
doc=nlp(article)
tokens=[token.text for token in doc if not token.is_stop]# add words in token which are not in stop words
print('Original article: ',article)
print()
print(doc)
print()
print(tokens)  #docs contain 'which' but it is not added to tokens as it is a stop word
# Out:
# Original article:  In computing, stop words are words which are filtered out before or after processing of natural language data (text).[1] Though "stop words" usually refers to the most common words in a language, there is no single universal list of stop words used by all natural language processing tools, and indeed not all tools even use such a list. Some tools specifically avoid removing these stop words to support phrase search.
#
# In computing, stop words are words which are filtered out before or after processing of natural language data (text).[1] Though "stop words" usually refers to the most common words in a language, there is no single universal list of stop words used by all natural language processing tools, and indeed not all tools even use such a list. Some tools specifically avoid removing these stop words to support phrase search.
#
# ['computing', ',', 'stop', 'words', 'words', 'filtered', 'processing', 'natural', 'language', 'data', '(', 'text).[1', ']', '"', 'stop', 'words', '"', 'usually', 'refers', 'common', 'words', 'language', ',', 'single', 'universal', 'list', 'stop', 'words', 'natural', 'language', 'processing', 'tools', ',', 'tools', 'use', 'list', '.', 'tools', 'specifically', 'avoid', 'removing', 'stop', 'words', 'support', 'phrase', 'search', '.']

# %% [markdown]
# # stopword_using nltk: method 2

# %%
import nltk
print('NLTK Version:%s'%(nltk.__version__))
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# NLTK Version:3.7
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91799\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk_stopwords=nltk.corpus.stopwords.words('english')
print('Number of stop words: ',len(nltk_stopwords))
print('First ten stop words: ',list(nltk_stopwords)[:10])
# Out:
# Number of stop words:  179
# First ten stop words:  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
tokens=nltk.tokenize.word_tokenize(article)
tokens=[i for i in tokens if not i in nltk_stopwords]#if the word is in tokens and not in stopwords it is assigned to tokens
print(article)
print()
print(tokens)#which,are,before..are stop words
# Out:
# In computing, stop words are words which are filtered out before or after processing of natural language data (text).[1] Though "stop words" usually refers to the most common words in a language, there is no single universal list of stop words used by all natural language processing tools, and indeed not all tools even use such a list. Some tools specifically avoid removing these stop words to support phrase search.
#
# ['In', 'computing', ',', 'stop', 'words', 'words', 'filtered', 'processing', 'natural', 'language', 'data', '(', 'text', ')', '.', '[', '1', ']', 'Though', '``', 'stop', 'words', "''", 'usually', 'refers', 'common', 'words', 'language', ',', 'single', 'universal', 'list', 'stop', 'words', 'used', 'natural', 'language', 'processing', 'tools', ',', 'indeed', 'tools', 'even', 'use', 'list', '.', 'Some', 'tools', 'specifically', 'avoid', 'removing', 'stop', 'words', 'support', 'phrase', 'search', '.']

# %% [markdown]
# # Customizing stop words

# %%
new_stopwords=['computing','processing','language']
stpwrd=nltk.corpus.stopwords.words('english')
stpwrd.extend(new_stopwords)
stpwrd
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'computing',
#  'processing',
#  'language']

# %%
# removing custom words

removing_custom_words=[words for words in tokens if not words in stpwrd]# add words which are in token  and dont add if it is in token
print(removing_custom_words) # removed the words computing, processing and language as they are in stopwords
# Out:
# ['In', ',', 'stop', 'words', 'words', 'filtered', 'natural', 'data', '(', 'text', ')', '.', '[', '1', ']', 'Though', '``', 'stop', 'words', "''", 'usually', 'refers', 'common', 'words', ',', 'single', 'universal', 'list', 'stop', 'words', 'used', 'natural', 'tools', ',', 'indeed', 'tools', 'even', 'use', 'list', '.', 'Some', 'tools', 'specifically', 'avoid', 'removing', 'stop', 'words', 'support', 'phrase', 'search', '.']

# %% [markdown]
# # Gram_implementation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#function to generate n-grams

def extract_ngrams(data,num):
    n_grams=ngrams(nltk.word_tokenize(data),num)
    print(n_grams)
    return[" ".join(grams) for grams in n_grams]

# %%
import nltk
from nltk.util import ngrams

# %%
data='A class is a blueprint'

# %%
print('1 gram: ',extract_ngrams(data,1))
print('2 gram: ',extract_ngrams(data,2))
print('3 gram: ',extract_ngrams(data,3))
print('4 gram: ',extract_ngrams(data,4))
print('5 gram: ',extract_ngrams(data,5))
# Out:
# <zip object at 0x0000023F6DA890C0>
# 1 gram:  ['A', 'class', 'is', 'a', 'blueprint']
# <zip object at 0x0000023F6DA89800>
# 2 gram:  ['A class', 'class is', 'is a', 'a blueprint']
# <zip object at 0x0000023F6DA89A40>
# 3 gram:  ['A class is', 'class is a', 'is a blueprint']
# <zip object at 0x0000023F6DA89C40>
# 4 gram:  ['A class is a', 'class is a blueprint']
# <zip object at 0x0000023F6DA89DC0>
# 5 gram:  ['A class is a blueprint']

# %% [markdown]
# ![image.png](attachment:image.png)
